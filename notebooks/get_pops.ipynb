# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import requests
from bs4 import BeautifulSoup
from itertools import chain
import re

# %%
pops.keys()
# Out:
# dict_keys(['Funko Heroes Series', 'Marvel Marvel Series', 'Star Wars Series', 'Funko Disney Series', 'Wwe Series', 'Wrestling Funko Series', 'World Of J K Rowling Funko Series', 'Popvinylsseries Game Thrones Series', 'Television Series', 'Movies Series', 'Popvinylsseries Animation Series', 'Popvinylsseries Games Series', 'Ad Icons Series', 'Rocks Series', 'Comics Series', 'Funko Rides Series', 'Board Games Series', 'Sports Funko Series', 'Saturday Night Live Funko Series', 'South Park Funko Series', 'Marvel Vs Capcom Funko Series', '8 Bit Funko Series', 'Muppets Series', 'Sesame Street Funko Series', 'Pets Funko Series', 'Little Pony Series', 'Funko Originals Series', 'Freddy Funko 2 Series', 'Funko Monsters Series', 'Funko Asia Series', 'Conan Obrien Funko Series', 'Holiday Series', 'Stan Lee Series', 'Books Series', 'Myths Funko Series', 'Royal Family Funko Series', 'Drag Queens Funko Series', 'Funko Vote Series', 'Garbage Pail Kids Funko Series', 'Diy Series', 'Classics Series', '
# ...

# %%
pops['Funko Disney Series']
# Out:
# [(1, 'Mickey Mouse'),
#  (1, 'Metallic Mickey Mouse SDCC LE'),
#  (1, 'B W Mickey Mouse LE D'),
#  (1, 'Diamond Edition Mickey Mouse Hot Topic'),
#  (1, 'Gold Mickey Mouse B N'),
#  (1, 'Green Blue Mickey'),
#  (1, 'Green Yellow Mickey'),
#  (1, 'Pink Purple Mickey Colorway Mickey Exhibition'),
#  (1, 'Yellow Orange Mickey Colorway Mickey Exhibition'),
#  (1, 'Orange Teal Mickey'),
#  (1, 'Peaches Cream Mickey'),
#  (1, 'Blue Purple Mickey'),
#  (1, 'DIY Mickey Mouse Michaels'),
#  (2, 'Buzz Lightyear'),
#  (3, 'Woody'),
#  (3, 'SF Giants Woody SAN FRAN PARK GIVEAWAY'),
#  (4, 'Sully'),
#  (4, 'Flocked Sulley SDCC'),
#  (5, 'Mike Wazowski'),
#  (5, 'Glow in the Dark Mike Wazowski SDCC'),
#  (6, 'Pinocchio'),
#  (7, 'Jiminy Cricket'),
#  (8, 'Snow White'),
#  (9, 'Maleficent'),
#  (10, 'Tinker Bell'),
#  (10, 'Glitter Tink HOT TOPIC'),
#  (10, 'Diamond Tinker Bell HT'),
#  (11, 'Cruella De Vil'),
#  (12, 'Stitch'),
#  (12, 'Flocked Stitch Fugitive Toys SDCC'),
#  (13, 'Lotso'),
# ...

# %%
import re
# Out:
# [(1, 'Batman', '01 – Batman'),
#  (1, 'Batman Metallic Chase', '01 – Batman (Metallic Chase)'),
#  (1, 'Blue Retro Batman SDCC', '01 – “Blue Retro” Batman (SDCC 2010)'),
#  (1,
#   'Metallic Blue Retro Batman SDCC',
#   '01 – Metallic “Blue Retro” Batman (SDCC 2010)'),
#  (1, 'Yellow Symbol Error Batman', '01 – “Yellow Symbol Error” Batman'),
#  (1,
#   'Yellow Error Metallic Chase Batman',
#   '01 – “Yellow Error” (Metallic Chase) Batman'),
#  (1, 'Flashpoint Batman NYCC', '01 – Flashpoint Batman (NYCC 2011)'),
#  (1,
#   'Bobblehead Batman Target Exclusive',
#   '01 Bobblehead Batman (Target Exclusive)'),
#  (1,
#   'Bobblehead Metallic Batman CHASE Target Exclusive',
#   '01=Bobblehead Metallic Batman {CHASE} (Target Exclusive)'),
#  (1,
#   'The New Batman Previews Exclusive',
#   '01 – “The New 52” Batman (Previews Exclusive)'),
#  (1,
#   'Yellow Rainbow Batman Ent Earth',
#   '01 – Yellow Rainbow Batman (Ent Earth)'),
#  (1,
#   'Purple Rainbow Batman Ent Earth',
# ...
